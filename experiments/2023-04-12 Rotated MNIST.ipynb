# %%
# %load_ext autoreload
# %autoreload 2

# %%
from adaptive_dg.datasets.domainbed.datasets import RotatedMNIST
from adaptive_dg.datasets.mnist.rotated import RotatedMNIST as RotatedMNISTNew

from adaptive_dg.datasets.transforms import Rotate

import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rc("figure", dpi=150)
plt.rc("legend", fontsize="small")
plt.style.use("dark_background")

# %%
r1 = RotatedMNIST("data", None, None)
r2 = RotatedMNISTNew("data")
# Out:
# 0
# 15
# 30
# 45
# 60
# 75
# ...

# %%
r1[0][0][0].shape
# Out:
# torch.Size([1, 28, 28])

# %%
r2[0][0].shape
# Out:
# torch.Size([28, 28])

# %%
fig, axes = plt.subplots(1, 2)

env = 4
idx = 7

axes[0].imshow(r1[env][idx][0].squeeze(), cmap="gray")
axes[1].imshow(r2.domain(env)[idx][0], cmap="gray")
plt.show()
# Out:
# [40000, 40001, 40002, 40003, 40004, 40005, 40006, 40007, 40008, 40009, 40010, 40011, 40012, 40013, 40014, 40015, 40016, 40017, 40018, 40019, 40020, 40021, 40022, 40023, 40024, 40025, 40026, 40027, 40028, 40029, 40030, 40031, 40032, 40033, 40034, 40035, 40036, 40037, 40038, 40039, 40040, 40041, 40042, 40043, 40044, 40045, 40046, 40047, 40048, 40049, 40050, 40051, 40052, 40053, 40054, 40055, 40056, 40057, 40058, 40059, 40060, 40061, 40062, 40063, 40064, 40065, 40066, 40067, 40068, 40069, 40070, 40071, 40072, 40073, 40074, 40075, 40076, 40077, 40078, 40079, 40080, 40081, 40082, 40083, 40084, 40085, 40086, 40087, 40088, 40089, 40090, 40091, 40092, 40093, 40094, 40095, 40096, 40097, 40098, 40099, 40100, 40101, 40102, 40103, 40104, 40105, 40106, 40107, 40108, 40109, 40110, 40111, 40112, 40113, 40114, 40115, 40116, 40117, 40118, 40119, 40120, 40121, 40122, 40123, 40124, 40125, 40126, 40127, 40128, 40129, 40130, 40131, 40132, 40133, 40134, 40135, 40136, 40137, 40138, 40139, 40140, 40141, 401
# ...

# %%
r = Rotate(90)
data, label, env = r2[2]
data = data.unsqueeze(0)

# %%
img, *_ = r(data, label, env)

plt.imshow(img.squeeze(), cmap="gray")
plt.show()
